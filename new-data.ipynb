# %%
# Работа с табличными данными
import pandas as pd
import numpy as np

# Преобразование признаков
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Визуализация
import plotly.express as px
import plotly.io as pio
pio.templates.default = 'plotly_dark'

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

from IPython.display import Markdown as md

from motorica.utils import *
from motorica.pipeline import LagWrapper

import optuna

import os

# %%
data = pd.read_csv('data/2024-12-04_12-22-13.emg8', sep=' ')
data = data[data['id'] >= 0]
omg_cols = [col for col in data.columns if 'omg' in col]
data.info()
data['id'] = data['id'] * 1000000
px.line(data[omg_cols + ['id']]).update_traces(line=dict(width=1)).show()

data['id'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5501 entries, 125 to 5625
# Data columns (total 43 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ts       5501 non-null   float64
#  1   td       5501 non-null   float64
#  2   omg0     5501 non-null   float64
#  3   omg1     5501 non-null   float64
#  4   omg2     5501 non-null   float64
#  5   omg3     5501 non-null   float64
#  6   omg4     5501 non-null   float64
#  7   omg5     5501 non-null   float64
#  8   omg6     5501 non-null   float64
#  9   omg7     5501 non-null   float64
#  10  omg8     5501 non-null   float64
#  11  omg9     5501 non-null   float64
#  12  omg10    5501 non-null   float64
#  13  omg11    5501 non-null   float64
#  14  omg12    5501 non-null   float64
#  15  omg13    5501 non-null   float64
#  16  omg14    5501 non-null   float64
#  17  omg15    5501 non-null   float64
#  18  emg0     5501 non-null   float64
#  19  emg1     5501 non-null   float64
# ...
